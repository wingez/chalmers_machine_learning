# %%
import numpy as np
import matplotlib.pyplot as plt

from system.model import simulate

# %%
result = simulate(seconds=0.1, target_current=7)



plt.subplot(5,1,1)
plt.plot(result.time,result.current,)
plt.xlabel("tid")
plt.ylabel("ström")
plt.show()
plt.plot(result.time,result.omega,)

plt.xlabel('tid')
plt.ylabel("omega")
plt.show()

fig = plt.figure()
ax = plt.axes()
#fig,ax = plt.subplots(figsize = (100,100))
for label,voltage in result.voltages.items():

  ax.scatter(result.time, voltage, label= label)

ax.set_xlabel("time (s)")
ax.set_ylabel("voltage (V)")
ax.legend()
#fig.show()
#plt.show()
